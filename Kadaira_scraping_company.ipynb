# %% [markdown]
# <a href="https://colab.research.google.com/github/tom2rd/Googlecolabutils/blob/master/Kadaira_scraping_company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# （財）建設業情報管理センターで公表されている経営事項審査（経審）結果に基づいて作成された経診情報（小平市内の工事を請けた会社）
# の情報から
#
# http://keishin.ullet.com
#
# 元データは、http://www.ciic.or.jp/index.html

# %%
import requests
from bs4 import BeautifulSoup
import re
import numpy as np

# Webページを取得して解析する
#load_url = "https://www.city.kodaira.tokyo.jp/kurashi/076/076079.html"
load_url="http://keishin.ullet.com/search/city/13211/pref/13.html#pref/13/city/13211"
base_url="http://keishin.ullet.com"
html = requests.get(load_url)
soup = BeautifulSoup(html.content, "html.parser")
#alists=soup.find_all('a')
#alists
cplists=soup.find_all('a', class_="company_name")
cpnamelists=[["0","0"],["1","1"]]
for cplist in cplists:
  cpnamelists.append([cplist.text,base_url+cplist.attrs["href"]])
pglists=soup.find_all('a',text=re.compile("P."))
pglists2=[]
for pglist in pglists:
 load_url=base_url+pglist.attrs["href"]
 html = requests.get(load_url)
 soup = BeautifulSoup(html.content, "html.parser")
 cplists=soup.find_all('a', class_="company_name")
 for cplist in cplists:
  cpnamelists.append([cplist.text,base_url+cplist.attrs["href"]])


cpnamelists
# Out:
# [['0', '0'],
#  ['1', '1'],
#  ['日立国際電気サービス', 'http://keishin.ullet.com/00-005669.html'],
#  ['国際電気テクノサービス', 'http://keishin.ullet.com/00-018220.html'],
#  ['国際電気テクノサービス', 'http://keishin.ullet.com/13-138509.html'],
#  ['高杉商事', 'http://keishin.ullet.com/00-013953.html'],
#  ['東京ガスタマライフバリュー', 'http://keishin.ullet.com/13-131437.html'],
#  ['山口建興', 'http://keishin.ullet.com/13-032602.html'],
#  ['ティ・ジェイホームサービス', 'http://keishin.ullet.com/00-021527.html'],
#  ['西武緑化管理', 'http://keishin.ullet.com/00-014991.html'],
#  ['蒼和', 'http://keishin.ullet.com/13-068799.html'],
#  ['武蔵産業', 'http://keishin.ullet.com/13-021509.html'],
#  ['加藤工務店', 'http://keishin.ullet.com/13-111942.html'],
#  ['久野建装', 'http://keishin.ullet.com/00-014544.html'],
#  ['日昇工業', 'http://keishin.ullet.com/13-006680.html'],
#  ['かじわら', 'http://keishin.ullet.com/13-079145.html'],
#  ['武蔵建設', 'http://keishin.ullet.com/13-102009.html'],
#  ['堀内電機', 'http://keishin.ullet.com/13-006390.html'],
# ...

# %%
cplists1=cpnamelists[2:]
cplists1
# Out:
# [['日立国際電気サービス', 'http://keishin.ullet.com/00-005669.html'],
#  ['国際電気テクノサービス', 'http://keishin.ullet.com/00-018220.html'],
#  ['国際電気テクノサービス', 'http://keishin.ullet.com/13-138509.html'],
#  ['高杉商事', 'http://keishin.ullet.com/00-013953.html'],
#  ['東京ガスタマライフバリュー', 'http://keishin.ullet.com/13-131437.html'],
#  ['山口建興', 'http://keishin.ullet.com/13-032602.html'],
#  ['ティ・ジェイホームサービス', 'http://keishin.ullet.com/00-021527.html'],
#  ['西武緑化管理', 'http://keishin.ullet.com/00-014991.html'],
#  ['蒼和', 'http://keishin.ullet.com/13-068799.html'],
#  ['武蔵産業', 'http://keishin.ullet.com/13-021509.html'],
#  ['加藤工務店', 'http://keishin.ullet.com/13-111942.html'],
#  ['久野建装', 'http://keishin.ullet.com/00-014544.html'],
#  ['日昇工業', 'http://keishin.ullet.com/13-006680.html'],
#  ['かじわら', 'http://keishin.ullet.com/13-079145.html'],
#  ['武蔵建設', 'http://keishin.ullet.com/13-102009.html'],
#  ['堀内電機', 'http://keishin.ullet.com/13-006390.html'],
#  ['岡電設工業', 'http://keishin.ullet.com/00-006041.html'],
# ...

# %%
i=0
for ii in cplists1:
  print(cplists1[i][1])
  i=i+1
#cplists1[1][0]
# Out:
# http://keishin.ullet.com/00-005669.html
# http://keishin.ullet.com/00-018220.html
# http://keishin.ullet.com/13-138509.html
# http://keishin.ullet.com/00-013953.html
# http://keishin.ullet.com/13-131437.html
# http://keishin.ullet.com/13-032602.html
# http://keishin.ullet.com/00-021527.html
# http://keishin.ullet.com/00-014991.html
# http://keishin.ullet.com/13-068799.html
# http://keishin.ullet.com/13-021509.html
# http://keishin.ullet.com/13-111942.html
# http://keishin.ullet.com/00-014544.html
# http://keishin.ullet.com/13-006680.html
# http://keishin.ullet.com/13-079145.html
# http://keishin.ullet.com/13-102009.html
# http://keishin.ullet.com/13-006390.html
# http://keishin.ullet.com/00-006041.html
# http://keishin.ullet.com/13-044589.html
# http://keishin.ullet.com/13-020189.html
# http://keishin.ullet.com/13-126648.html
# http://keishin.ullet.com/13-020149.html
# http://keishin.ullet.com/13-013694.html
# http://keishin.ullet.com/13-016190.html
# ...
